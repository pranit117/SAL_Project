# %%
import os

# Path for phoneme files
phoneme_path = '/media/monica/128 GB/htkCorrectedLab/lab/txt/phn'
file_prefix = 'ISLE_SESS0003_BLOCKD01_'
file_suffix = '_sprt1.txt'

output_list = []

# Function to read phoneme data and extract nuclei
def get_nuclei_from_phn(file_path):
    nuclei = []
    try:
        with open(file_path, 'r') as phn_file:
            for line in phn_file:
                parts = line.strip().split()
                if len(parts) == 3 and parts[2] not in ['SIL']:  # Ignore silence
                    start, end, phoneme = float(parts[0]), float(parts[1]), parts[2]
                    if phoneme in {'A', 'AA', 'AE', 'AH', 'AO', 'AW', 'AY', 'EH', 'ER', 'EY', 'IH', 'IY', 'OW', 'OY', 'UH', 'UW'}:  # Only vowels
                        nuclei.append((phoneme, start, end))
    except FileNotFoundError:
        print(f"Phoneme file not found: {file_path}")
    except Exception as e:
        print(f"Error reading phoneme file {file_path}: {e}")
    return nuclei

for i in range(1, 82):  # From 1 to 81
    phn_file = os.path.join(phoneme_path, f"{file_prefix}{i:02d}{file_suffix}")
    wav_file_name = f"{file_prefix}{i:02d}_sprt1.wav"

    try:
        # Extract nuclei from the phoneme file
        nuclei = get_nuclei_from_phn(phn_file)

        # Generate output for the phoneme nuclei
        for nucleus in nuclei:
            nucleus_phoneme, nucleus_start, nucleus_end = nucleus

            # Fix the f-string with proper quoting for the nucleus information
            output_line = (
                f'"{wav_file_name}", [({nucleus_phoneme}, {nucleus_start:.4f}, {nucleus_end:.4f})]'
            )
            output_list.append(output_line)

    except FileNotFoundError:
        print(f"Phoneme file not found: {phn_file}")
        continue
    except Exception as e:
        print(f"Error processing {phn_file}: {e}")
        continue

# Print all outputs
for line in output_list:
    print(line)
# Out:
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [(AY, 0.1400, 0.2000)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [(EH, 0.3200, 0.3800)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [(AY, 0.6100, 0.9000)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [(AO, 1.0700, 1.1500)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [(EY, 1.2500, 1.5000)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [(AY, 0.1800, 0.2800)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [(EH, 0.4400, 0.5500)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [(UW, 0.7900, 1.0700)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [(AO, 1.2100, 1.2900)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [(OW, 1.4900, 1.8500)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [(AY, 0.2900, 0.3600)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [(EH, 0.4800, 0.5500)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [(AE, 0.7000, 0.9300)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [(AO, 1.1600, 1.2600)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [(EH, 1.3700, 1.6300)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [(AY, 0.2300, 0.2600)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [(EH, 0.3800, 0.4300)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [(EY, 0.6100, 0.8700)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [(AO, 1.0900, 1.1600)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [(AY, 1.3200, 1.6100)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [(AY, 0.3000, 0.3900)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [(EH, 0.4800, 0.5400)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [(AY, 0.7600, 1.0600)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [(AO, 1.2400, 1.3000)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [(EH, 1.4200, 1.5700)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [(ER, 1.7000, 1.9000)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [(AY, 0.1100, 0.1700)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [(EY, 0.3300, 0.4600)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [(OW, 0.7500, 1.0800)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [(AO, 1.1500, 1.2200)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [(AO, 1.4300, 1.5800)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [(OW, 1.6300, 1.8500)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [(AY, 0.0200, 0.0500)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [(EH, 0.1000, 0.1600)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [(OW, 0.3700, 0.6400)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [(AO, 0.9000, 0.9500)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [(AY, 1.0600, 1.1000)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [(AO, 1.1900, 1.4000)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [(IH, 1.4400, 1.4700)]
# "ISLE_SESS0003_BLOCKD01_08_sprt1.wav", [(AY, 0.2300, 0.3300)]
# "ISLE_SESS0003_BLOCKD01_08_sprt1.wav", [(EH, 0.4100, 0.4700)]
# "ISLE_SESS0003_BLOCKD01_08_sprt1.wav", [(UW, 0.6700, 0.9000)]
# "ISLE_SESS0003_BLOCKD01_08_sprt1.wav", [(AO, 1.1300, 1.2500)]
# "ISLE_SESS0003_BLOCKD01_08_sprt1.wav", [(UW, 1.4000, 1.6500)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav", [(AY, 0.0700, 0.1600)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav", [(EH, 0.2500, 0.3000)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav", [(IY, 0.5400, 0.7100)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav", [(AO, 0.8400, 0.9400)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav",
)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [(EH, 2.5400, 2.7300)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [(AH, 3.0100, 3.1800)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [(ER, 3.3000, 3.4700)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [(AW, 3.8500, 4.0200)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [(OY, 4.0600, 4.1400)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [(AE, 4.2700, 4.4500)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [(IH, 0.2500, 0.2900)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [(EY, 0.5000, 0.6700)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [(IH, 0.7200, 0.8100)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [(AW, 1.2800, 1.4800)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [(UH, 1.8600, 1.9100)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [(IY, 1.9600, 2.0400)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [(AE, 2.1400, 2.3200)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [(EH, 2.7900, 2.8400)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [(AA, 3.1100, 3.3000)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [(IH, 0.6900, 0.7800)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [(EY, 1.0700, 1.1900)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [(IH, 1.2600, 1.3300)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [(EH, 1.6300, 1.6700)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [(OW, 1.7400, 1.7800)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [(AA, 1.9900, 2.1500)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [(AW, 2.6500, 2.7900)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [(IY, 2.8600, 2.9000)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [(ER, 3.1100, 3.3400)]

# %%
import scipy.io

# Path to the .mat file
file_path = '/media/monica/128 GB/htkCorrectedLab/lab/mat/sylStress/ISLE_SESS0003_BLOCKD01_01_sprt1.mat'

# Load the .mat file
mat_contents = scipy.io.loadmat(file_path)

# Display the available keys in the .mat file
print("Keys in the .mat file:", mat_contents.keys())

# Access specific data fields (replace 'spurtSyl' with your desired key)
spurtSyl = mat_contents.get('spurtSyl', None)
spurtSylTimes = mat_contents.get('spurtSylTimes', None)
spurtStress = mat_contents.get('spurtStress', None)

# Display data for specific keys
print("spurtSyl data:", spurtSyl)
print("spurtSylTimes data:", spurtSylTimes)
print("spurtStress data:", spurtStress)
# Out:
# Keys in the .mat file: dict_keys(['__header__', '__version__', '__globals__', 'spurtSyl', 'spurtSylTimes', 'spurtStress'])
# spurtSyl data: [[array(['AY'], dtype='<U2')]
#  [array(['S EH D'], dtype='<U6')]
#  [array(['W AY T'], dtype='<U6')]
#  [array(['N AO T'], dtype='<U6')]
#  [array(['B EY T S'], dtype='<U8')]]
# spurtSylTimes data: [[0.14 0.2 ]
#  [0.2  0.47]
#  [0.47 0.99]
#  [0.99 1.19]
#  [1.19 1.69]]
# spurtStress data: [[array(['P'], dtype='<U1')]
#  [array(['P'], dtype='<U1')]
#  [array(['P'], dtype='<U1')]
#  [array(['P'], dtype='<U1')]
#  [array(['P'], dtype='<U1')]]

# %%
import scipy.io

# Path to the .mat file
file_path = '/media/monica/128 GB/htkCorrectedLab/lab/mat/sylStress/ISLE_SESS0003_BLOCKD01_01.mat'

# Load the .mat file
mat_contents = scipy.io.loadmat(file_path)

# Extract the relevant data
spurtSyl = mat_contents.get('spurtSyl', [])
spurtSylTimes = mat_contents.get('spurtSylTimes', [])

# Prepare the output format
wav_file_name = "ISLE_SESS0003_BLOCKD01_01_sprt1.wav"
syllable_data = [
    (syllable[0][0], float(times[0]), float(times[1]))
    for syllable, times in zip(spurtSyl, spurtSylTimes)
]

# Generate the required output string
output = f'"{wav_file_name}", {syllable_data},'
print(output)
# Out:
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [('AY', 0.14, 0.2), ('S EH D', 0.2, 0.47), ('W AY T', 0.47, 0.99), ('N AO T', 0.99, 1.19), ('B EY T S', 1.19, 1.69)],

# %%
import scipy.io
import os

# Base path and file naming structure
base_path = '/media/monica/128 GB/htkCorrectedLab/lab/mat/sylStress/'
file_prefix = 'ISLE_SESS0003_BLOCKD01_'
file_suffix = '_sprt1.mat'
# Path for phoneme files
phoneme_path = '/media/monica/128 GB/htkCorrectedLab/lab/txt/phn'

# Function to read phoneme data and extract nuclei within a syllable time range
def get_nuclei_from_phn(file_path, syllable_start, syllable_end):
    nuclei = []
    try:
        with open(file_path, 'r') as phn_file:
            for line in phn_file:
                parts = line.strip().split()
                if len(parts) == 3 and parts[2] not in ['SIL']:  # Ignore silence
                    start, end, phoneme = float(parts[0]), float(parts[1]), parts[2]
                    # Check if the phoneme is a vowel and its timing overlaps with the syllable
                    if phoneme in {'A', 'AA', 'AE', 'AH', 'AO', 'AW', 'AY', 'EH', 'ER', 'EY', 'IH', 'IY', 'OW', 'OY', 'UH', 'UW', 'AX', 'AI'} and (start >= syllable_start and end <= syllable_end):
                        nuclei.append((phoneme, start, end))
    except FileNotFoundError:
        print(f"Phoneme file not found: {file_path}")
    except Exception as e:
        print(f"Error reading phoneme file {file_path}: {e}")
    return nuclei

# Prepare to iterate through all file indices
output_list = []

for i in range(1, 82):  # From 1 to 81
    mat_file_name = f"{file_prefix}{i:02d}{file_suffix}"
    wav_file_name = f"{file_prefix}{i:02d}_sprt1.wav"
    mat_file_path = os.path.join(base_path, mat_file_name)
    phn_file_path = os.path.join(phoneme_path, f"{file_prefix}{i:02d}{file_suffix.replace('.mat', '.txt')}")
    
    # Load the .mat file
    try:
        mat_contents = scipy.io.loadmat(mat_file_path)
        spurtSyl = mat_contents.get('spurtSyl', [])
        spurtSylTimes = mat_contents.get('spurtSylTimes', [])

        # Prepare syllable data and align with nuclei
        if len(spurtSyl) != len(spurtSylTimes):
            print(f"Warning: Mismatched syllable and time lengths in {mat_file_name}")
        
        for syllable, times in zip(spurtSyl, spurtSylTimes):
            syllable_start = float(times[0])
            syllable_end = float(times[1])
            
            # Extract nuclei (vowel phonemes) within the syllable time range
            nuclei = get_nuclei_from_phn(phn_file_path, syllable_start, syllable_end)
            
            # If no nuclei found, skip this syllable
            if not nuclei:
                continue
            
            # Collect syllable and nucleus data
            syllable_str = " ".join([phoneme[0] for phoneme in syllable])  # Assuming syllable[0] contains phonemes
            for nucleus in nuclei:
                nucleus_phoneme, nucleus_start, nucleus_end = nucleus
                # Format the output for syllable and nucleus
                output = (
                    f'"{wav_file_name}", [("{syllable_str}", {syllable_start:.4f}, {syllable_end:.4f})], '
                    f"[({nucleus_phoneme}, {nucleus_start:.4f}, {nucleus_end:.4f})]"
                )
                output_list.append(output)

    except FileNotFoundError:
        print(f"File not found: {mat_file_path}")
        continue
    except Exception as e:
        print(f"Error processing {mat_file_path}: {e}")
        continue

# Print all outputs
for line in output_list:
    print(line)
# Out:
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("AY", 0.1400, 0.2000)], [(AY, 0.1400, 0.2000)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("S EH D", 0.2000, 0.4700)], [(EH, 0.3200, 0.3800)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("W AY T", 0.4700, 0.9900)], [(AY, 0.6100, 0.9000)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("N AO T", 0.9900, 1.1900)], [(AO, 1.0700, 1.1500)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("B EY T S", 1.1900, 1.6900)], [(EY, 1.2500, 1.5000)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("AY", 0.1800, 0.2800)], [(AY, 0.1800, 0.2800)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("S EH D", 0.2800, 0.5800)], [(EH, 0.4400, 0.5500)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("N Y UW", 0.5800, 1.0700)], [(UW, 0.7900, 1.0700)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("N AO T", 1.1400, 1.3400)], [(AO, 1.2100, 1.2900)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("N OW", 1.3400, 1.8500)], [(OW, 1.4900, 1.8500)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("AY", 0.2900, 0.3600)], [(AY, 0.2900, 0.3600)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("S EH D", 0.3600, 0.6100)], [(EH, 0.4800, 0.5500)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("B AE D", 0.6100, 0.9700)], [(AE, 0.7000, 0.9300)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("N AO T", 0.9700, 1.3100)], [(AO, 1.1600, 1.2600)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("B EH D", 1.3100, 1.7700)], [(EH, 1.3700, 1.6300)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("AY", 0.2300, 0.2600)], [(AY, 0.2300, 0.2600)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [
]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("AX N D", 2.4400, 2.6900)], [(AX, 2.4400, 2.6200)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("AX", 2.6900, 2.7200)], [(AX, 2.6900, 2.7200)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("R EH D", 2.7200, 2.9200)], [(EH, 2.7900, 2.8400)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("S K AA R F", 2.9200, 3.4100)], [(AA, 3.1100, 3.3000)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("HH IH Z", 0.6500, 0.9000)], [(IH, 0.6900, 0.7800)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("W EY", 0.9000, 1.1900)], [(EY, 1.0700, 1.1900)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("R IH NG", 1.1900, 1.4100)], [(IH, 1.2600, 1.3300)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX", 1.4100, 1.4800)], [(AX, 1.4100, 1.4800)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("Y EH", 1.4800, 1.6700)], [(EH, 1.6300, 1.6700)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("L OW", 1.6700, 1.7800)], [(OW, 1.7400, 1.7800)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("S K AA R F", 1.7800, 2.2900)], [(AA, 1.9900, 2.1500)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX N", 2.2900, 2.4200)], [(AX, 2.2900, 2.3400)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX", 2.4200, 2.4800)], [(AX, 2.4200, 2.4800)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("F L AW", 2.4800, 2.7900)], [(AW, 2.6500, 2.7900)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX", 2.7900, 2.8200)], [(AX, 2.7900, 2.8200)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("R IY", 2.8200, 2.9000)], [(IY, 2.8600, 2.9000)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("SH ER T", 2.9000, 3.4800)], [(ER, 3.1100, 3.3400)]

# %%
import scipy.io
import os

# Base path and file naming structure
base_path = '/media/monica/128 GB/htkCorrectedLab/lab/mat/sylStress/'
file_prefix = 'ISLE_SESS0003_BLOCKD01_'
file_suffix = '_sprt1.mat'

# Prepare to iterate through all file indices
output_list = []

for i in range(1, 82):  # From 1 to 81
    mat_file_name = f"{file_prefix}{i:02d}{file_suffix}"
    wav_file_name = f"{file_prefix}{i:02d}_sprt1.wav"
    file_path = os.path.join(base_path, mat_file_name)
    
    # Load the .mat file
    try:
        mat_contents = scipy.io.loadmat(file_path)
        spurtSyl = mat_contents.get('spurtSyl', [])
        spurtSylTimes = mat_contents.get('spurtSylTimes', [])

        # Prepare syllable data and output in the exact format
        for syllable, times in zip(spurtSyl, spurtSylTimes):
            start_time = float(times[0])
            end_time = float(times[1])
            syllable_text = syllable[0][0]  # Assumed to be the first element of the syllable
            output = f'"{wav_file_name}", [("{syllable_text}", {start_time}, {end_time})]'
            output_list.append(output)

    except FileNotFoundError:
        print(f"File not found: {file_path}")
        continue
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        continue

# Print all outputs
for line in output_list:
    print(line)
# Out:
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("AY", 0.14, 0.2)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("S EH D", 0.2, 0.47)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("W AY T", 0.47, 0.99)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("N AO T", 0.99, 1.19)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("B EY T S", 1.19, 1.69)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("AY", 0.18, 0.28)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("S EH D", 0.28, 0.58)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("N Y UW", 0.58, 1.07)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("N AO T", 1.14, 1.34)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("N OW", 1.34, 1.85)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("AY", 0.29, 0.36)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("S EH D", 0.36, 0.61)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("B AE D", 0.61, 0.97)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("N AO T", 0.97, 1.31)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("B EH D", 1.31, 1.77)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("AY", 0.23, 0.26)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("S EH D", 0.26, 0.46)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("L EY T S", 0.46, 1.04)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("N AO T", 1.04, 1.23)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("S AY T", 1.23, 1.82)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("AY", 0.3, 0.39)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("S EH D", 0.39, 0.59)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("F AY T", 0.59, 1.2)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("N AO T", 1.2, 1.36)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("S EH N", 1.36, 1.6)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("T ER", 1.6, 1.9)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("AY", 0.11, 0.17)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("S EY", 0.17, 0.46)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("D AX", 0.46, 0.56)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("Z N OW", 0.56, 1.08)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("N AO T", 1.1, 1.28)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("T AX", 1.28, 1.37)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("M AO", 1.37, 1.58)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("R OW", 1.58, 1.85)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("AY", 0.02, 0.05)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("S EH", 0.05, 0.16)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("D AX", 0.16, 0.23)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("K L OW S", 0.23, 0.78)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("N AO T", 0.85, 1.02)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("B AY", 1.02, 1.1)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("AX", 1.1, 1.15)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("L AO", 1.15, 1.4)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("ZH IH", 1.4, 1.47)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [
]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("SH IY", 0.73, 0.97)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("W EY", 0.97, 1.31)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("R IH NG", 1.31, 1.62)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("SH IH Z", 1.73, 2.05)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("W EY", 2.05, 2.28)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("R IH NG", 2.28, 2.55)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("AH", 2.55, 2.69)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("L EH", 2.69, 2.86)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("DH ER", 2.86, 2.98)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("JH AE", 2.98, 3.31)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("K IH", 3.31, 3.4)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("T AX", 3.4, 3.56)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("AX", 3.6, 3.65)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("N AX", 3.65, 3.84)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("K AO R", 3.86, 4.12)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("D UW", 4.12, 4.26)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("R OY", 4.26, 4.37)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("T R AW", 4.37, 4.73)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("Z ER Z", 4.73, 5.15)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("W AO T S", 0.13, 0.38)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("HH IY", 0.38, 0.59)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("W EY", 0.59, 0.81)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("R IH NG", 0.81, 1.17)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("HH IY Z", 1.41, 1.59)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("W EY", 1.59, 1.81)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("R IH NG", 1.81, 2.06)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("AX", 2.09, 2.2)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("B IH D", 2.2, 2.41)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("B EH ZH", 2.5, 2.91)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("ZH AH M", 2.91, 3.23)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("P ER", 3.23, 3.47)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("AX N D", 3.47, 3.67)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("AX", 3.67, 3.71)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("K AW", 3.78, 4.02)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("B OY", 4.02, 4.14)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("HH AE T", 4.14, 4.64)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("SH IH", 0.1, 0.29)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("Z AX", 0.29, 0.4)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("W EY", 0.4, 0.67)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("R IH NG", 0.67, 0.99)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("AX", 1.04, 1.13)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("B R AW", 1.13, 1.48)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("N AX", 1.48, 1.68)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("HH W UH", 1.79, 1.91)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("L IY", 1.91, 2.04)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("HH AE T", 2.09, 2.44)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("AX N D", 2.44, 2.69)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("AX", 2.69, 2.72)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("R EH D", 2.72, 2.92)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("S K AA R F", 2.92, 3.41)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("HH IH Z", 0.65, 0.9)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("W EY", 0.9, 1.19)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("R IH NG", 1.19, 1.41)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX", 1.41, 1.48)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("Y EH", 1.48, 1.67)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("L OW", 1.67, 1.78)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("S K AA R F", 1.78, 2.29)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX N", 2.29, 2.42)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX", 2.42, 2.48)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("F L AW", 2.48, 2.79)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX", 2.79, 2.82)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("R IY", 2.82, 2.9)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("SH ER T", 2.9, 3.48)]

# %%
import scipy.io
import os

# Base path and file naming structure
base_path = '/media/monica/128 GB/htkCorrectedLab/lab/mat/sylStress/'
file_prefix = 'ISLE_SESS0003_BLOCKD01_'
file_suffix = '_sprt1.mat'

# Prepare to iterate through all file indices
output_list = []

for i in range(1, 82):  # From 1 to 81
    mat_file_name = f"{file_prefix}{i:02d}{file_suffix}"
    wav_file_name = f"{file_prefix}{i:02d}_sprt1.wav"
    file_path = os.path.join(base_path, mat_file_name)
    
    # Load the .mat file
    try:
        mat_contents = scipy.io.loadmat(file_path)
        spurtSyl = mat_contents.get('spurtSyl', [])
        spurtSylTimes = mat_contents.get('spurtSylTimes', [])

        # Prepare syllable data and output in the exact format
        for syllable, times in zip(spurtSyl, spurtSylTimes):
            start_time = float(times[0])
            end_time = float(times[1])
            syllable_text = syllable[0][0]  # Assumed to be the first element of the syllable
            output = f'"{wav_file_name}", [("{syllable_text}", {start_time}, {end_time})]'
            output_list.append(output)

    except FileNotFoundError:
        print(f"File not found: {file_path}")
        continue
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        continue

# Print all outputs
for line in output_list:
    print(line)
# Out:
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("AY", 0.14, 0.2)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("S EH D", 0.2, 0.47)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("W AY T", 0.47, 0.99)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("N AO T", 0.99, 1.19)]
# "ISLE_SESS0003_BLOCKD01_01_sprt1.wav", [("B EY T S", 1.19, 1.69)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("AY", 0.18, 0.28)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("S EH D", 0.28, 0.58)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("N Y UW", 0.58, 1.07)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("N AO T", 1.14, 1.34)]
# "ISLE_SESS0003_BLOCKD01_02_sprt1.wav", [("N OW", 1.34, 1.85)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("AY", 0.29, 0.36)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("S EH D", 0.36, 0.61)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("B AE D", 0.61, 0.97)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("N AO T", 0.97, 1.31)]
# "ISLE_SESS0003_BLOCKD01_03_sprt1.wav", [("B EH D", 1.31, 1.77)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("AY", 0.23, 0.26)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("S EH D", 0.26, 0.46)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("L EY T S", 0.46, 1.04)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("N AO T", 1.04, 1.23)]
# "ISLE_SESS0003_BLOCKD01_04_sprt1.wav", [("S AY T", 1.23, 1.82)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("AY", 0.3, 0.39)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("S EH D", 0.39, 0.59)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("F AY T", 0.59, 1.2)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("N AO T", 1.2, 1.36)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("S EH N", 1.36, 1.6)]
# "ISLE_SESS0003_BLOCKD01_05_sprt1.wav", [("T ER", 1.6, 1.9)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("AY", 0.11, 0.17)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("S EY", 0.17, 0.46)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("D AX", 0.46, 0.56)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("Z N OW", 0.56, 1.08)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("N AO T", 1.1, 1.28)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("T AX", 1.28, 1.37)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("M AO", 1.37, 1.58)]
# "ISLE_SESS0003_BLOCKD01_06_sprt1.wav", [("R OW", 1.58, 1.85)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("AY", 0.02, 0.05)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("S EH", 0.05, 0.16)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("D AX", 0.16, 0.23)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("K L OW S", 0.23, 0.78)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("N AO T", 0.85, 1.02)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("B AY", 1.02, 1.1)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("AX", 1.1, 1.15)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("L AO", 1.15, 1.4)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("ZH IH", 1.4, 1.47)]
# "ISLE_SESS0003_BLOCKD01_07_sprt1.wav", [("K AX L", 1.47, 1.8)]
# "ISLE_SESS0003_BLOCKD01_08_sprt1.wav", [("AY", 0.23, 0.33)]
# "ISLE_SESS0003_BLOCKD01_08_sprt1.wav", [("S EH D", 0.33, 0.55)]
# "ISLE_SESS0003_BLOCKD01_08_sprt1.wav", [("P UW T", 0.63, 1.01)]
# "ISLE_SESS0003_BLOCKD01_08_sprt1.wav", [("N AO T", 1.01, 1.28)]
# "ISLE_SESS0003_BLOCKD01_08_sprt1.wav", [("B L UW", 1.28, 1.65)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav", [("AY", 0.07, 0.16)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav", [("S EH", 0.16, 0.3)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav", [("D AX", 0.3, 0.38)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav", [("L IY V", 0.38, 0.75)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav", [("N AO T", 0.75, 0.97)]
# "ISLE_SESS0003_BLOCKD01_09_sprt1.wav", [("B ER D", 1.02, 1.43)]
# "ISLE_SESS0003_BLOCKD01_10_sprt1.wav", [("AY", 0.19, 0.23)]
# "ISLE_SESS0003_BLOCKD01_10_sprt1.wav", [("S EH D", 0.23, 0.44)]
# "ISLE_SESS0003_BLOCKD01_10_sprt1.wav", [("AX", 0.44, 0.48)]
# "ISLE_SESS0003_BLOCKD01_10_sprt1.wav", [("L OW N", 0.48, 0.9)]
# "ISLE_SESS0003_BLOCKD01_10_sprt1.wav", [("N AO T", 0.92, 1.12)]
# "ISLE_SESS0003_BLOCKD01_10_sprt1.wav", [("G OW N", 1.17, 1.68)]
# "ISLE_SESS0003_BLOCKD01_11_sprt1.wav", [("AY", 0.12, 0.2)]
# "ISLE_SESS0003_BLOCKD01_11_sprt1.wav", [("S EH D", 0.2, 0.4)]
# "ISLE_SESS0003_BLOCKD01_11_sprt1.wav", [("F R EY Z", 0.4, 0.97)]
# "ISLE_SESS0003_BLOCKD01_11_sprt1.wav", [("N AO T", 0.97, 1.16)]
# "ISLE_SESS0003_BLOCKD01_11_sprt1.wav", [("B AA R", 1.23, 1.61)]
# "ISLE_SESS0003_BLOCKD01_12_sprt1.wav", [("AY", 0.28, 0.39)]
# "ISLE_SESS0003_BLOCKD01_12_sprt1.wav", [("S EH D", 0.39, 0.65)]
# "ISLE_SESS0003_BLOCKD01_12_sprt1.wav", [("G AA T", 0.72, 1.18)]
# "ISLE_SESS0003_BLOCKD01_12_sprt1.wav", [("N AO T", 1.22, 1.35)]
# "ISLE_SESS0003_BLOCKD01_12_sprt1.wav", [("G OW T", 1.4, 1.9)]
# "ISLE_SESS0003_BLOCKD01_13_sprt1.wav", [("AY", 0.25, 0.39)]
# "ISLE_SESS0003_BLOCKD01_13_sprt1.wav", [("S EH D", 0.39, 0.66)]
# "ISLE_SESS0003_BLOCKD01_13_sprt1.wav", [("M IY T", 0.66, 1.22)]
# "ISLE_SESS0003_BLOCKD01_13_sprt1.wav", [("N AO", 1.24, 1.46)]
# "ISLE_SESS0003_BLOCKD01_13_sprt1.wav", [("W AO", 1.46, 1.69)]
# "ISLE_SESS0003_BLOCKD01_13_sprt1.wav", [("T ER", 1.69, 2.01)]
# "ISLE_SESS0003_BLOCKD01_14_sprt1.wav", [("AY", 0.26, 0.35)]
# "ISLE_SESS0003_BLOCKD01_14_sprt1.wav", [("S EH D", 0.35, 0.6)]
# "ISLE_SESS0003_BLOCKD01_14_sprt1.wav", [("CH IY P", 0.66, 1.06)]
# "ISLE_SESS0003_BLOCKD01_14_sprt1.wav", [("N AO D", 1.11, 1.33)]
# "ISLE_SESS0003_BLOCKD01_14_sprt1.wav", [("AH", 1.33, 1.52)]
# "ISLE_SESS0003_BLOCKD01_14_sprt1.wav", [("D ER", 1.52, 1.81)]
# "ISLE_SESS0003_BLOCKD01_15_sprt1.wav", [("AY", 0.33, 0.49)]
# "ISLE_SESS0003_BLOCKD01_15_sprt1.wav", [("S EH D", 0.49, 0.92)]
# "ISLE_SESS0003_BLOCKD01_15_sprt1.wav", [("TH R UW", 0.92, 1.39)]
# "ISLE_SESS0003_BLOCKD01_15_sprt1.wav", [("N AO T", 1.44, 1.66)]
# "ISLE_SESS0003_BLOCKD01_15_sprt1.wav", [("TH OW", 1.66, 2.13)]
# "ISLE_SESS0003_BLOCKD01_16_sprt1.wav", [("AY", 0.34, 0.44)]
# "ISLE_SESS0003_BLOCKD01_16_sprt1.wav", [("S EH D", 0.44, 0.68)]
# "ISLE_SESS0003_BLOCKD01_16_sprt1.wav", [("L EH T", 0.68, 1.19)]
# "ISLE_SESS0003_BLOCKD01_16_sprt1.wav", [("N AO T", 1.19, 1.43)]
# "ISLE_SESS0003_BLOCKD01_16_sprt1.wav", [("L IY V", 1.43, 1.96)]
# "ISLE_SESS0003_BLOCKD01_17_sprt1.wav", [("AY", 0.16, 0.23)]
# "ISLE_SESS0003_BLOCKD01_17_sprt1.wav", [("S EH D", 0.23, 0.5)]
# "ISLE_SESS0003_BLOCKD01_17_sprt1.wav", [("B UW K", 0.5, 0.95)]
# "ISLE_SESS0003_BLOCKD01_17_sprt1.wav", [("N AO T", 0.99, 1.15)]
# "ISLE_SESS0003_BLOCKD01_17_sprt1.wav", [("D OW", 1.19, 1.51)]
# "ISLE_SESS0003_BLOCKD01_18_sprt1.wav", [("AY", 0.15, 0.26)]
# "ISLE_SESS0003_BLOCKD01_18_sprt1.wav", [("S EH D", 0.26, 0.47)]
# "ISLE_SESS0003_BLOCKD01_18_sprt1.wav", [("K L AY M", 0.47, 0.86)]
# "ISLE_SESS0003_BLOCKD01_18_sprt1.wav", [("B IH NG", 0.86, 1.12)]
# "ISLE_SESS0003_BLOCKD01_18_sprt1.wav", [("N AO T", 1.18, 1.36)]
# "ISLE_SESS0003_BLOCKD01_18_sprt1.wav", [("CH IY Z", 1.36, 1.87)]
# "ISLE_SESS0003_BLOCKD01_19_sprt1.wav", [("AY", 0.17, 0.24)]
# "ISLE_SESS0003_BLOCKD01_19_sprt1.wav", [("S EH D", 0.24, 0.48)]
# "ISLE_SESS0003_BLOCKD01_19_sprt1.wav", [("S AY", 0.48, 0.68)]
# "ISLE_SESS0003_BLOCKD01_19_sprt1.wav", [("K AO", 0.68, 0.98)]
# "ISLE_SESS0003_BLOCKD01_19_sprt1.wav", [("L AO", 0.98, 1.16)]
# "ISLE_SESS0003_BLOCKD01_19_sprt1.wav", [("ZH IY", 1.16, 1.32)]
# "ISLE_SESS0003_BLOCKD01_19_sprt1.wav", [("N AO T", 1.32, 1.52)]
# "ISLE_SESS0003_BLOCKD01_19_sprt1.wav", [("N Y UW", 1.52, 1.67)]
# "ISLE_SESS0003_BLOCKD01_19_sprt1.wav", [("M AE", 1.67, 1.93)]
# "ISLE_SESS0003_BLOCKD01_19_sprt1.wav", [("T IH K", 1.93, 2.2)]
# "ISLE_SESS0003_BLOCKD01_20_sprt1.wav", [("AY", 0.2, 0.29)]
# "ISLE_SESS0003_BLOCKD01_20_sprt1.wav", [("S EH", 0.29, 0.43)]
# "ISLE_SESS0003_BLOCKD01_20_sprt1.wav", [("D AX", 0.43, 0.56)]
# "ISLE_SESS0003_BLOCKD01_20_sprt1.wav", [("TH IH N", 0.56, 1.13)]
# "ISLE_SESS0003_BLOCKD01_20_sprt1.wav", [("N AO T", 1.17, 1.37)]
# "ISLE_SESS0003_BLOCKD01_20_sprt1.wav", [("SH IY", 1.37, 1.83)]
# "ISLE_SESS0003_BLOCKD01_20_sprt1.wav", [("P AX", 1.83, 2.08)]
# "ISLE_SESS0003_BLOCKD01_21_sprt1.wav", [("AY", 0.03, 0.12)]
# "ISLE_SESS0003_BLOCKD01_21_sprt1.wav", [("S EH D", 0.12, 0.37)]
# "ISLE_SESS0003_BLOCKD01_21_sprt1.wav", [("HH EY T", 0.37, 0.95)]
# "ISLE_SESS0003_BLOCKD01_21_sprt1.wav", [("N AO S", 0.97, 1.23)]
# "ISLE_SESS0003_BLOCKD01_21_sprt1.wav", [("T S IH N", 1.23, 1.67)]
# "ISLE_SESS0003_BLOCKD01_22_sprt1.wav", [("AY", 0.23, 0.32)]
# "ISLE_SESS0003_BLOCKD01_22_sprt1.wav", [("S EH D", 0.32, 0.58)]
# "ISLE_SESS0003_BLOCKD01_22_sprt1.wav", [("W OW N T", 0.58, 1.07)]
# "ISLE_SESS0003_BLOCKD01_22_sprt1.wav", [("N AO T", 1.07, 1.3)]
# "ISLE_SESS0003_BLOCKD01_22_sprt1.wav", [("AH", 1.33, 1.53)]
# "ISLE_SESS0003_BLOCKD01_22_sprt1.wav", [("D ER", 1.53, 1.81)]
# "ISLE_SESS0003_BLOCKD01_23_sprt1.wav", [("AY", 0.28, 0.34)]
# "ISLE_SESS0003_BLOCKD01_23_sprt1.wav", [("S EH D", 0.34, 0.54)]
# "ISLE_SESS0003_BLOCKD01_23_sprt1.wav", [("S IH", 0.54, 0.67)]
# "ISLE_SESS0003_BLOCKD01_23_sprt1.wav", [("K AX", 0.67, 0.75)]
# "ISLE_SESS0003_BLOCKD01_23_sprt1.wav", [("DH IH S", 0.75, 1.17)]
# "ISLE_SESS0003_BLOCKD01_23_sprt1.wav", [("N AO M", 1.17, 1.34)]
# "ISLE_SESS0003_BLOCKD01_23_sprt1.wav", [("B AY", 1.34, 1.52)]
# "ISLE_SESS0003_BLOCKD01_23_sprt1.wav", [("AO", 1.52, 1.63)]
# "ISLE_SESS0003_BLOCKD01_23_sprt1.wav", [("L AX", 1.63, 1.79)]
# "ISLE_SESS0003_BLOCKD01_23_sprt1.wav", [("ZH IY", 1.79, 2.02)]
# "ISLE_SESS0003_BLOCKD01_24_sprt1.wav", [("AY", 0.23, 0.31)]
# "ISLE_SESS0003_BLOCKD01_24_sprt1.wav", [("S EH D", 0.31, 0.51)]
# "ISLE_SESS0003_BLOCKD01_24_sprt1.wav", [("HH AH T", 0.51, 0.9)]
# "ISLE_SESS0003_BLOCKD01_24_sprt1.wav", [("N AO T", 0.9, 1.1)]
# "ISLE_SESS0003_BLOCKD01_24_sprt1.wav", [("SH UW R", 1.1, 1.6)]
# "ISLE_SESS0003_BLOCKD01_25_sprt1.wav", [("AY", 0.14, 0.2)]
# "ISLE_SESS0003_BLOCKD01_25_sprt1.wav", [("S EH", 0.2, 0.38)]
# "ISLE_SESS0003_BLOCKD01_25_sprt1.wav", [("D AX", 0.38, 0.48)]
# "ISLE_SESS0003_BLOCKD01_25_sprt1.wav", [("Z L IY P", 0.48, 1.05)]
# "ISLE_SESS0003_BLOCKD01_25_sprt1.wav", [("N AO T", 1.05, 1.26)]
# "ISLE_SESS0003_BLOCKD01_25_sprt1.wav", [("HH OW P", 1.26, 1.73)]
# "ISLE_SESS0003_BLOCKD01_26_sprt1.wav", [("AY", 0.19, 0.24)]
# "ISLE_SESS0003_BLOCKD01_26_sprt1.wav", [("S EH D", 0.24, 0.44)]
# "ISLE_SESS0003_BLOCKD01_26_sprt1.wav", [("K AO L", 0.52, 0.91)]
# "ISLE_SESS0003_BLOCKD01_26_sprt1.wav", [("N AO", 0.91, 1.12)]
# "ISLE_SESS0003_BLOCKD01_26_sprt1.wav", [("SH AE L", 1.12, 1.69)]
# "ISLE_SESS0003_BLOCKD01_27_sprt1.wav", [("AY", 0.02, 0.16)]
# "ISLE_SESS0003_BLOCKD01_27_sprt1.wav", [("S EH D", 0.16, 0.41)]
# "ISLE_SESS0003_BLOCKD01_27_sprt1.wav", [("D OW N T", 0.45, 0.91)]
# "ISLE_SESS0003_BLOCKD01_27_sprt1.wav", [("N AO T", 0.91, 1.16)]
# "ISLE_SESS0003_BLOCKD01_27_sprt1.wav", [("SH UW", 1.16, 1.54)]
# "ISLE_SESS0003_BLOCKD01_27_sprt1.wav", [("D ER", 1.54, 1.8)]
# "ISLE_SESS0003_BLOCKD01_28_sprt1.wav", [("AY", 0.26, 0.32)]
# "ISLE_SESS0003_BLOCKD01_28_sprt1.wav", [("S EH", 0.32, 0.47)]
# "ISLE_SESS0003_BLOCKD01_28_sprt1.wav", [("D AX", 0.47, 0.57)]
# "ISLE_SESS0003_BLOCKD01_28_sprt1.wav", [("W UW", 0.57, 0.94)]
# "ISLE_SESS0003_BLOCKD01_28_sprt1.wav", [("D AX", 0.94, 1.09)]
# "ISLE_SESS0003_BLOCKD01_28_sprt1.wav", [("N AO", 1.09, 1.23)]
# "ISLE_SESS0003_BLOCKD01_28_sprt1.wav", [("F IH L", 1.23, 1.63)]
# "ISLE_SESS0003_BLOCKD01_28_sprt1.wav", [("M AX", 1.63, 1.8)]
# "ISLE_SESS0003_BLOCKD01_29_sprt1.wav", [("AY", 0.17, 0.24)]
# "ISLE_SESS0003_BLOCKD01_29_sprt1.wav", [("S EH D", 0.24, 0.51)]
# "ISLE_SESS0003_BLOCKD01_29_sprt1.wav", [("S P AO R T", 0.51, 1.15)]
# "ISLE_SESS0003_BLOCKD01_29_sprt1.wav", [("N AO T", 1.15, 1.42)]
# "ISLE_SESS0003_BLOCKD01_29_sprt1.wav", [("W AY N", 1.42, 2.15)]
# "ISLE_SESS0003_BLOCKD01_30_sprt1.wav", [("AO", 0.07, 0.33)]
# "ISLE_SESS0003_BLOCKD01_30_sprt1.wav", [("N EH S T", 0.33, 0.61)]
# "ISLE_SESS0003_BLOCKD01_30_sprt1.wav", [("N AO T", 0.61, 0.83)]
# "ISLE_SESS0003_BLOCKD01_30_sprt1.wav", [("S L AE P T", 0.83, 1.48)]
# "ISLE_SESS0003_BLOCKD01_31_sprt1.wav", [("W AO T", 0.17, 0.35)]
# "ISLE_SESS0003_BLOCKD01_31_sprt1.wav", [("IH Z", 0.35, 0.47)]
# "ISLE_SESS0003_BLOCKD01_31_sprt1.wav", [("SH", 0.47, 0.64)]
# "ISLE_SESS0003_BLOCKD01_31_sprt1.wav", [("D R EH NG", 0.64, 0.98)]
# "ISLE_SESS0003_BLOCKD01_31_sprt1.wav", [("K IH NG", 0.98, 1.28)]
# "ISLE_SESS0003_BLOCKD01_31_sprt1.wav", [("AX", 1.4, 1.53)]
# "ISLE_SESS0003_BLOCKD01_31_sprt1.wav", [("K AH P", 1.53, 1.81)]
# "ISLE_SESS0003_BLOCKD01_31_sprt1.wav", [("AO", 1.81, 1.88)]
# "ISLE_SESS0003_BLOCKD01_31_sprt1.wav", [("K AO", 1.9, 2.11)]
# "ISLE_SESS0003_BLOCKD01_31_sprt1.wav", [("F IY", 2.11, 2.38)]
# "ISLE_SESS0003_BLOCKD01_32_sprt1.wav", [("AX", 0.37, 0.49)]
# "ISLE_SESS0003_BLOCKD01_32_sprt1.wav", [("K AE N", 0.58, 0.85)]
# "ISLE_SESS0003_BLOCKD01_32_sprt1.wav", [("AX V", 0.85, 0.94)]
# "ISLE_SESS0003_BLOCKD01_32_sprt1.wav", [("S AY", 0.94, 1.3)]
# "ISLE_SESS0003_BLOCKD01_32_sprt1.wav", [("D ER", 1.3, 1.57)]
# "ISLE_SESS0003_BLOCKD01_33_sprt1.wav", [("AX", 0.31, 0.39)]
# "ISLE_SESS0003_BLOCKD01_33_sprt1.wav", [("G L AH S", 0.39, 0.71)]
# "ISLE_SESS0003_BLOCKD01_33_sprt1.wav", [("AO", 0.71, 0.81)]
# "ISLE_SESS0003_BLOCKD01_33_sprt1.wav", [("W AY N", 0.81, 1.45)]
# "ISLE_SESS0003_BLOCKD01_34_sprt1.wav", [("AX", 0.3, 0.38)]
# "ISLE_SESS0003_BLOCKD01_34_sprt1.wav", [("B AO", 0.38, 0.56)]
# "ISLE_SESS0003_BLOCKD01_34_sprt1.wav", [("T AX L", 0.56, 0.75)]
# "ISLE_SESS0003_BLOCKD01_34_sprt1.wav", [("AO", 0.75, 0.84)]
# "ISLE_SESS0003_BLOCKD01_34_sprt1.wav", [("W AO", 0.84, 1.07)]
# "ISLE_SESS0003_BLOCKD01_34_sprt1.wav", [("T ER", 1.07, 1.36)]
# "ISLE_SESS0003_BLOCKD01_35_sprt1.wav", [("AX", 0.23, 0.31)]
# "ISLE_SESS0003_BLOCKD01_35_sprt1.wav", [("M AH G", 0.31, 0.56)]
# "ISLE_SESS0003_BLOCKD01_35_sprt1.wav", [("AO", 0.56, 0.66)]
# "ISLE_SESS0003_BLOCKD01_35_sprt1.wav", [("T IY", 0.66, 1.09)]
# "ISLE_SESS0003_BLOCKD01_36_sprt1.wav", [("W EY R", 0.02, 0.15)]
# "ISLE_SESS0003_BLOCKD01_36_sprt1.wav", [("AA R", 0.15, 0.24)]
# "ISLE_SESS0003_BLOCKD01_36_sprt1.wav", [("DH", 0.24, 0.31)]
# "ISLE_SESS0003_BLOCKD01_36_sprt1.wav", [("S ER", 0.31, 0.61)]
# "ISLE_SESS0003_BLOCKD01_36_sprt1.wav", [("T IH N", 0.61, 0.87)]
# "ISLE_SESS0003_BLOCKD01_36_sprt1.wav", [("IH N", 0.94, 1.03)]
# "ISLE_SESS0003_BLOCKD01_36_sprt1.wav", [("AX", 1.03, 1.09)]
# "ISLE_SESS0003_BLOCKD01_36_sprt1.wav", [("P AA R K", 1.15, 1.56)]
# "ISLE_SESS0003_BLOCKD01_37_sprt1.wav", [("IH N", 0.07, 0.25)]
# "ISLE_SESS0003_BLOCKD01_37_sprt1.wav", [("AX", 0.35, 0.57)]
# "ISLE_SESS0003_BLOCKD01_37_sprt1.wav", [("P AH", 0.57, 0.65)]
# "ISLE_SESS0003_BLOCKD01_37_sprt1.wav", [("B AX", 0.65, 0.7)]
# "ISLE_SESS0003_BLOCKD01_38_sprt1.wav", [("AE T", 0.15, 0.36)]
# "ISLE_SESS0003_BLOCKD01_38_sprt1.wav", [("HH OW M", 0.44, 1.0)]
# "ISLE_SESS0003_BLOCKD01_39_sprt1.wav", [("B AY", 0.35, 0.47)]
# "ISLE_SESS0003_BLOCKD01_39_sprt1.wav", [("AX", 0.47, 0.57)]
# "ISLE_SESS0003_BLOCKD01_39_sprt1.wav", [("R IY", 0.57, 0.84)]
# "ISLE_SESS0003_BLOCKD01_39_sprt1.wav", [("V ER", 0.84, 1.13)]
# "ISLE_SESS0003_BLOCKD01_40_sprt1.wav", [("IH N", 0.47, 0.55)]
# "ISLE_SESS0003_BLOCKD01_40_sprt1.wav", [("DH AX", 0.55, 0.66)]
# "ISLE_SESS0003_BLOCKD01_40_sprt1.wav", [("TH IY", 0.66, 0.9)]
# "ISLE_SESS0003_BLOCKD01_40_sprt1.wav", [("AX", 0.9, 0.95)]
# "ISLE_SESS0003_BLOCKD01_40_sprt1.wav", [("T ER", 0.95, 1.27)]
# "ISLE_SESS0003_BLOCKD01_41_sprt1.wav", [("AO N", 0.27, 0.4)]
# "ISLE_SESS0003_BLOCKD01_41_sprt1.wav", [("AX", 0.4, 0.46)]
# "ISLE_SESS0003_BLOCKD01_41_sprt1.wav", [("B EH N CH", 0.46, 0.86)]
# "ISLE_SESS0003_BLOCKD01_41_sprt1.wav", [("IH N", 0.86, 0.94)]
# "ISLE_SESS0003_BLOCKD01_41_sprt1.wav", [("DH AX", 0.94, 1.01)]
# "ISLE_SESS0003_BLOCKD01_41_sprt1.wav", [("P AA R K", 1.07, 1.47)]
# "ISLE_SESS0003_BLOCKD01_42_sprt1.wav", [("AW", 0.24, 0.38)]
# "ISLE_SESS0003_BLOCKD01_42_sprt1.wav", [("S AY D", 0.38, 0.64)]
# "ISLE_SESS0003_BLOCKD01_42_sprt1.wav", [("AH", 0.64, 0.68)]
# "ISLE_SESS0003_BLOCKD01_42_sprt1.wav", [("P AH", 0.68, 1.03)]
# "ISLE_SESS0003_BLOCKD01_42_sprt1.wav", [("B AX", 1.03, 1.18)]
# "ISLE_SESS0003_BLOCKD01_42_sprt1.wav", [("B AY", 1.18, 1.34)]
# "ISLE_SESS0003_BLOCKD01_42_sprt1.wav", [("DH AX", 1.34, 1.47)]
# "ISLE_SESS0003_BLOCKD01_42_sprt1.wav", [("R IY", 1.47, 1.66)]
# "ISLE_SESS0003_BLOCKD01_42_sprt1.wav", [("V ER", 1.66, 1.89)]
# "ISLE_SESS0003_BLOCKD01_43_sprt1.wav", [("IH N", 0.24, 0.38)]
# "ISLE_SESS0003_BLOCKD01_43_sprt1.wav", [("AX", 0.38, 0.47)]
# "ISLE_SESS0003_BLOCKD01_43_sprt1.wav", [("P AA R K", 0.54, 0.98)]
# "ISLE_SESS0003_BLOCKD01_43_sprt1.wav", [("N IY R", 1.0, 1.24)]
# "ISLE_SESS0003_BLOCKD01_43_sprt1.wav", [("AX", 1.24, 1.29)]
# "ISLE_SESS0003_BLOCKD01_43_sprt1.wav", [("P AA TH", 1.29, 1.88)]
# "ISLE_SESS0003_BLOCKD01_44_sprt1.wav", [("B AX", 0.04, 0.12)]
# "ISLE_SESS0003_BLOCKD01_44_sprt1.wav", [("S AY D", 0.12, 0.44)]
# "ISLE_SESS0003_BLOCKD01_44_sprt1.wav", [("AX", 0.44, 0.48)]
# "ISLE_SESS0003_BLOCKD01_44_sprt1.wav", [("T R IY", 0.48, 0.7)]
# "ISLE_SESS0003_BLOCKD01_44_sprt1.wav", [("IH N", 0.7, 0.76)]
# "ISLE_SESS0003_BLOCKD01_44_sprt1.wav", [("AX", 0.76, 0.81)]
# "ISLE_SESS0003_BLOCKD01_44_sprt1.wav", [("P AA R K", 0.81, 1.3)]
# "ISLE_SESS0003_BLOCKD01_45_sprt1.wav", [("B AX", 0.29, 0.37)]
# "ISLE_SESS0003_BLOCKD01_45_sprt1.wav", [("S AY D", 0.37, 0.65)]
# "ISLE_SESS0003_BLOCKD01_45_sprt1.wav", [("DH AX", 0.65, 0.71)]
# "ISLE_SESS0003_BLOCKD01_45_sprt1.wav", [("F AY", 0.71, 1.06)]
# "ISLE_SESS0003_BLOCKD01_45_sprt1.wav", [("ER", 1.06, 1.21)]
# "ISLE_SESS0003_BLOCKD01_45_sprt1.wav", [("IH N", 1.21, 1.29)]
# "ISLE_SESS0003_BLOCKD01_45_sprt1.wav", [("AX", 1.29, 1.36)]
# "ISLE_SESS0003_BLOCKD01_45_sprt1.wav", [("P AH", 1.36, 1.71)]
# "ISLE_SESS0003_BLOCKD01_45_sprt1.wav", [("B AX", 1.71, 1.9)]
# "ISLE_SESS0003_BLOCKD01_46_sprt1.wav", [("IH N", 0.24, 0.37)]
# "ISLE_SESS0003_BLOCKD01_46_sprt1.wav", [("AX", 0.37, 0.47)]
# "ISLE_SESS0003_BLOCKD01_46_sprt1.wav", [("B OW T", 0.47, 0.93)]
# "ISLE_SESS0003_BLOCKD01_46_sprt1.wav", [("AO N", 0.95, 1.09)]
# "ISLE_SESS0003_BLOCKD01_46_sprt1.wav", [("DH AX", 1.09, 1.18)]
# "ISLE_SESS0003_BLOCKD01_46_sprt1.wav", [("R IY", 1.18, 1.38)]
# "ISLE_SESS0003_BLOCKD01_46_sprt1.wav", [("V ER", 1.38, 1.64)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("W EY R", 0.17, 0.39)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("IH Z", 0.39, 0.47)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("DH AX", 0.47, 0.6)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("K AH P", 0.66, 1.01)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("AO N", 1.41, 1.59)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("DH IY", 1.59, 1.77)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("EH ZH", 1.77, 1.99)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("AO V", 1.99, 2.09)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("DH AX", 2.09, 2.15)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("T EY", 2.15, 2.47)]
# "ISLE_SESS0003_BLOCKD01_47_sprt1.wav", [("B AX L", 2.47, 2.79)]
# "ISLE_SESS0003_BLOCKD01_48_sprt1.wav", [("IH N", 0.09, 0.22)]
# "ISLE_SESS0003_BLOCKD01_48_sprt1.wav", [("DH AX", 0.22, 0.29)]
# "ISLE_SESS0003_BLOCKD01_48_sprt1.wav", [("M IY", 0.29, 0.5)]
# "ISLE_SESS0003_BLOCKD01_48_sprt1.wav", [("D AX L", 0.5, 0.63)]
# "ISLE_SESS0003_BLOCKD01_48_sprt1.wav", [("AO V", 0.63, 0.74)]
# "ISLE_SESS0003_BLOCKD01_48_sprt1.wav", [("DH AX", 0.74, 0.81)]
# "ISLE_SESS0003_BLOCKD01_48_sprt1.wav", [("T EY", 0.81, 1.13)]
# "ISLE_SESS0003_BLOCKD01_48_sprt1.wav", [("B AX L", 1.13, 1.42)]
# "ISLE_SESS0003_BLOCKD01_49_sprt1.wav", [("N EH K S T", 0.18, 0.57)]
# "ISLE_SESS0003_BLOCKD01_49_sprt1.wav", [("T AX", 0.57, 0.65)]
# "ISLE_SESS0003_BLOCKD01_49_sprt1.wav", [("DH AX", 0.65, 0.75)]
# "ISLE_SESS0003_BLOCKD01_49_sprt1.wav", [("JH AH G", 0.82, 1.14)]
# "ISLE_SESS0003_BLOCKD01_49_sprt1.wav", [("AO N", 1.14, 1.22)]
# "ISLE_SESS0003_BLOCKD01_49_sprt1.wav", [("DH AX", 1.22, 1.28)]
# "ISLE_SESS0003_BLOCKD01_49_sprt1.wav", [("T EY", 1.28, 1.63)]
# "ISLE_SESS0003_BLOCKD01_49_sprt1.wav", [("B AX L", 1.63, 1.92)]
# "ISLE_SESS0003_BLOCKD01_50_sprt1.wav", [("IH N", 0.12, 0.23)]
# "ISLE_SESS0003_BLOCKD01_50_sprt1.wav", [("DH AX", 0.23, 0.31)]
# "ISLE_SESS0003_BLOCKD01_50_sprt1.wav", [("K AH", 0.31, 0.58)]
# "ISLE_SESS0003_BLOCKD01_50_sprt1.wav", [("B AO D", 0.58, 1.07)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("W AO T", 0.16, 0.34)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("K AE N", 0.34, 0.58)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("Y UW", 0.58, 0.68)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("S IH", 0.68, 0.82)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("IH N", 0.82, 0.89)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("DH AX", 0.89, 0.95)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("P IH K", 0.95, 1.2)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("CH ER", 1.2, 1.6)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("AH", 1.88, 2.01)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("JH IH N", 2.01, 2.31)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("JH ER", 2.31, 2.46)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("B IH", 2.46, 2.64)]
# "ISLE_SESS0003_BLOCKD01_51_sprt1.wav", [("S K IH T", 2.64, 3.12)]
# "ISLE_SESS0003_BLOCKD01_52_sprt1.wav", [("AX", 0.06, 0.13)]
# "ISLE_SESS0003_BLOCKD01_52_sprt1.wav", [("S IH NG", 0.13, 0.37)]
# "ISLE_SESS0003_BLOCKD01_52_sprt1.wav", [("G ER", 0.37, 0.5)]
# "ISLE_SESS0003_BLOCKD01_52_sprt1.wav", [("S IH NG", 0.5, 0.825)]
# "ISLE_SESS0003_BLOCKD01_52_sprt1.wav", [("G IH NG", 0.825, 1.08)]
# "ISLE_SESS0003_BLOCKD01_53_sprt1.wav", [("AX", 0.11, 0.18)]
# "ISLE_SESS0003_BLOCKD01_53_sprt1.wav", [("M AH N Z", 0.18, 0.43)]
# "ISLE_SESS0003_BLOCKD01_53_sprt1.wav", [("F IH NG", 0.43, 0.73)]
# "ISLE_SESS0003_BLOCKD01_53_sprt1.wav", [("G ER", 0.73, 1.01)]
# "ISLE_SESS0003_BLOCKD01_54_sprt1.wav", [("AX", 0.29, 0.35)]
# "ISLE_SESS0003_BLOCKD01_54_sprt1.wav", [("B EH L", 0.35, 0.61)]
# "ISLE_SESS0003_BLOCKD01_54_sprt1.wav", [("R IH NG", 0.61, 0.825)]
# "ISLE_SESS0003_BLOCKD01_54_sprt1.wav", [("G ER", 0.825, 1.11)]
# "ISLE_SESS0003_BLOCKD01_55_sprt1.wav", [("W AO T", 0.02, 0.12)]
# "ISLE_SESS0003_BLOCKD01_55_sprt1.wav", [("IH Z", 0.12, 0.33)]
# "ISLE_SESS0003_BLOCKD01_55_sprt1.wav", [("DH IH S", 0.33, 0.55)]
# "ISLE_SESS0003_BLOCKD01_55_sprt1.wav", [("B IH L", 0.57, 0.86)]
# "ISLE_SESS0003_BLOCKD01_55_sprt1.wav", [("D IH NG", 0.86, 1.09)]
# "ISLE_SESS0003_BLOCKD01_55_sprt1.wav", [("AH", 1.15, 1.25)]
# "ISLE_SESS0003_BLOCKD01_55_sprt1.wav", [("P AW", 1.25, 1.49)]
# "ISLE_SESS0003_BLOCKD01_55_sprt1.wav", [("ER", 1.49, 1.54)]
# "ISLE_SESS0003_BLOCKD01_55_sprt1.wav", [("S T AA", 1.54, 1.88)]
# "ISLE_SESS0003_BLOCKD01_55_sprt1.wav", [("SH AX N", 1.88, 2.22)]
# "ISLE_SESS0003_BLOCKD01_56_sprt1.wav", [("AA", 0.2, 0.39)]
# "ISLE_SESS0003_BLOCKD01_56_sprt1.wav", [("R EY L", 0.39, 0.66)]
# "ISLE_SESS0003_BLOCKD01_56_sprt1.wav", [("W EY", 0.66, 0.81)]
# "ISLE_SESS0003_BLOCKD01_56_sprt1.wav", [("S T EY", 0.81, 1.15)]
# "ISLE_SESS0003_BLOCKD01_56_sprt1.wav", [("SH AX N", 1.15, 1.56)]
# "ISLE_SESS0003_BLOCKD01_57_sprt1.wav", [("AX", 0.17, 0.27)]
# "ISLE_SESS0003_BLOCKD01_57_sprt1.wav", [("B AH S", 0.27, 0.48)]
# "ISLE_SESS0003_BLOCKD01_57_sprt1.wav", [("T ER", 0.48, 0.77)]
# "ISLE_SESS0003_BLOCKD01_57_sprt1.wav", [("M IH", 0.77, 0.85)]
# "ISLE_SESS0003_BLOCKD01_57_sprt1.wav", [("N AX L", 0.85, 1.17)]
# "ISLE_SESS0003_BLOCKD01_58_sprt1.wav", [("AX N", 0.02, 0.16)]
# "ISLE_SESS0003_BLOCKD01_58_sprt1.wav", [("EY", 0.16, 0.39)]
# "ISLE_SESS0003_BLOCKD01_58_sprt1.wav", [("P AO R", 0.39, 0.65)]
# "ISLE_SESS0003_BLOCKD01_58_sprt1.wav", [("T ER", 0.65, 0.9)]
# "ISLE_SESS0003_BLOCKD01_58_sprt1.wav", [("M IH", 0.9, 1.0)]
# "ISLE_SESS0003_BLOCKD01_58_sprt1.wav", [("N AX L", 1.0, 1.32)]
# "ISLE_SESS0003_BLOCKD01_59_sprt1.wav", [("AX N", 0.34, 0.49)]
# "ISLE_SESS0003_BLOCKD01_59_sprt1.wav", [("AA R T", 0.49, 0.82)]
# "ISLE_SESS0003_BLOCKD01_59_sprt1.wav", [("G AA", 0.82, 0.98)]
# "ISLE_SESS0003_BLOCKD01_59_sprt1.wav", [("L AX", 0.98, 1.14)]
# "ISLE_SESS0003_BLOCKD01_59_sprt1.wav", [("R IY", 1.14, 1.37)]
# "ISLE_SESS0003_BLOCKD01_60_sprt1.wav", [("W AO S", 0.09, 0.38)]
# "ISLE_SESS0003_BLOCKD01_60_sprt1.wav", [("IH N", 0.38, 0.45)]
# "ISLE_SESS0003_BLOCKD01_60_sprt1.wav", [("DH", 0.45, 0.51)]
# "ISLE_SESS0003_BLOCKD01_60_sprt1.wav", [("P EH", 0.54, 0.79)]
# "ISLE_SESS0003_BLOCKD01_60_sprt1.wav", [("CH ER", 0.79, 1.17)]
# "ISLE_SESS0003_BLOCKD01_60_sprt1.wav", [("AX", 1.37, 1.48)]
# "ISLE_SESS0003_BLOCKD01_60_sprt1.wav", [("P AH", 1.55, 1.84)]
# "ISLE_SESS0003_BLOCKD01_60_sprt1.wav", [("B AX", 1.84, 2.0)]
# "ISLE_SESS0003_BLOCKD01_61_sprt1.wav", [("AX", 0.03, 0.13)]
# "ISLE_SESS0003_BLOCKD01_61_sprt1.wav", [("M AW TH", 0.13, 0.67)]
# "ISLE_SESS0003_BLOCKD01_62_sprt1.wav", [("AX", 0.05, 0.12)]
# "ISLE_SESS0003_BLOCKD01_62_sprt1.wav", [("SH UH P", 0.12, 0.5)]
# "ISLE_SESS0003_BLOCKD01_63_sprt1.wav", [("AX", 0.16, 0.26)]
# "ISLE_SESS0003_BLOCKD01_63_sprt1.wav", [("B IY N", 0.33, 0.81)]
# "ISLE_SESS0003_BLOCKD01_64_sprt1.wav", [("AX", 0.1, 0.19)]
# "ISLE_SESS0003_BLOCKD01_64_sprt1.wav", [("P ER N", 0.26, 0.62)]
# "ISLE_SESS0003_BLOCKD01_65_sprt1.wav", [("TH R IY", 0.17, 0.39)]
# "ISLE_SESS0003_BLOCKD01_65_sprt1.wav", [("T R IY", 0.39, 0.89)]
# "ISLE_SESS0003_BLOCKD01_65_sprt1.wav", [("Z AX", 0.89, 1.03)]
# "ISLE_SESS0003_BLOCKD01_66_sprt1.wav", [("S AH M", 0.08, 0.29)]
# "ISLE_SESS0003_BLOCKD01_66_sprt1.wav", [("T R AE", 0.29, 0.64)]
# "ISLE_SESS0003_BLOCKD01_66_sprt1.wav", [("ZH UH R", 0.64, 0.94)]
# "ISLE_SESS0003_BLOCKD01_67_sprt1.wav", [("AX", 0.14, 0.21)]
# "ISLE_SESS0003_BLOCKD01_67_sprt1.wav", [("P AE", 0.29, 0.72)]
# "ISLE_SESS0003_BLOCKD01_68_sprt1.wav", [("AX", 0.16, 0.22)]
# "ISLE_SESS0003_BLOCKD01_68_sprt1.wav", [("S AH M", 0.22, 0.78)]
# "ISLE_SESS0003_BLOCKD01_69_sprt1.wav", [("AX", 0.2, 0.26)]
# "ISLE_SESS0003_BLOCKD01_69_sprt1.wav", [("SH IY", 0.26, 0.76)]
# "ISLE_SESS0003_BLOCKD01_69_sprt1.wav", [("P AX", 0.76, 1.0)]
# "ISLE_SESS0003_BLOCKD01_70_sprt1.wav", [("AX", 0.18, 0.25)]
# "ISLE_SESS0003_BLOCKD01_70_sprt1.wav", [("P AH P", 0.32, 0.7)]
# "ISLE_SESS0003_BLOCKD01_71_sprt1.wav", [("AX", 0.03, 0.06)]
# "ISLE_SESS0003_BLOCKD01_71_sprt1.wav", [("TH AH M", 0.06, 0.58)]
# "ISLE_SESS0003_BLOCKD01_72_sprt1.wav", [("AX", 0.04, 0.1)]
# "ISLE_SESS0003_BLOCKD01_72_sprt1.wav", [("M AW S", 0.1, 0.78)]
# "ISLE_SESS0003_BLOCKD01_73_sprt1.wav", [("AX", 0.14, 0.23)]
# "ISLE_SESS0003_BLOCKD01_73_sprt1.wav", [("B IH N", 0.23, 0.63)]
# "ISLE_SESS0003_BLOCKD01_74_sprt1.wav", [("AH", 0.17, 0.29)]
# "ISLE_SESS0003_BLOCKD01_74_sprt1.wav", [("T R IY", 0.29, 0.75)]
# "ISLE_SESS0003_BLOCKD01_75_sprt1.wav", [("S AH M", 0.03, 0.24)]
# "ISLE_SESS0003_BLOCKD01_75_sprt1.wav", [("K L AO S", 0.24, 0.76)]
# "ISLE_SESS0003_BLOCKD01_76_sprt1.wav", [("AX", 0.2, 0.26)]
# "ISLE_SESS0003_BLOCKD01_76_sprt1.wav", [("B L AW Z", 0.26, 0.9)]
# "ISLE_SESS0003_BLOCKD01_77_sprt1.wav", [("AX", 0.02, 0.08)]
# "ISLE_SESS0003_BLOCKD01_77_sprt1.wav", [("T EH", 0.08, 0.23)]
# "ISLE_SESS0003_BLOCKD01_77_sprt1.wav", [("L AX", 0.23, 0.36)]
# "ISLE_SESS0003_BLOCKD01_77_sprt1.wav", [("V IY", 0.36, 0.6)]
# "ISLE_SESS0003_BLOCKD01_77_sprt1.wav", [("ZH AX N", 0.6, 0.89)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("W AO T S", 0.4, 0.73)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("SH IY", 0.73, 0.97)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("W EY", 0.97, 1.31)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("R IH NG", 1.31, 1.62)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("SH IH Z", 1.73, 2.05)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("W EY", 2.05, 2.28)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("R IH NG", 2.28, 2.55)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("AH", 2.55, 2.69)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("L EH", 2.69, 2.86)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("DH ER", 2.86, 2.98)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("JH AE", 2.98, 3.31)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("K IH", 3.31, 3.4)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("T AX", 3.4, 3.56)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("AX", 3.6, 3.65)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("N AX", 3.65, 3.84)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("K AO R", 3.86, 4.12)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("D UW", 4.12, 4.26)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("R OY", 4.26, 4.37)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("T R AW", 4.37, 4.73)]
# "ISLE_SESS0003_BLOCKD01_78_sprt1.wav", [("Z ER Z", 4.73, 5.15)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("W AO T S", 0.13, 0.38)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("HH IY", 0.38, 0.59)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("W EY", 0.59, 0.81)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("R IH NG", 0.81, 1.17)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("HH IY Z", 1.41, 1.59)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("W EY", 1.59, 1.81)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("R IH NG", 1.81, 2.06)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("AX", 2.09, 2.2)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("B IH D", 2.2, 2.41)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("B EH ZH", 2.5, 2.91)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("ZH AH M", 2.91, 3.23)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("P ER", 3.23, 3.47)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("AX N D", 3.47, 3.67)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("AX", 3.67, 3.71)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("K AW", 3.78, 4.02)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("B OY", 4.02, 4.14)]
# "ISLE_SESS0003_BLOCKD01_79_sprt1.wav", [("HH AE T", 4.14, 4.64)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("SH IH", 0.1, 0.29)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("Z AX", 0.29, 0.4)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("W EY", 0.4, 0.67)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("R IH NG", 0.67, 0.99)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("AX", 1.04, 1.13)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("B R AW", 1.13, 1.48)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("N AX", 1.48, 1.68)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("HH W UH", 1.79, 1.91)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("L IY", 1.91, 2.04)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("HH AE T", 2.09, 2.44)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("AX N D", 2.44, 2.69)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("AX", 2.69, 2.72)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("R EH D", 2.72, 2.92)]
# "ISLE_SESS0003_BLOCKD01_80_sprt1.wav", [("S K AA R F", 2.92, 3.41)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("HH IH Z", 0.65, 0.9)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("W EY", 0.9, 1.19)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("R IH NG", 1.19, 1.41)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX", 1.41, 1.48)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("Y EH", 1.48, 1.67)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("L OW", 1.67, 1.78)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("S K AA R F", 1.78, 2.29)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX N", 2.29, 2.42)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX", 2.42, 2.48)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("F L AW", 2.48, 2.79)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("AX", 2.79, 2.82)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("R IY", 2.82, 2.9)]
# "ISLE_SESS0003_BLOCKD01_81_sprt1.wav", [("SH ER T", 2.9, 3.48)]

# %%
import scipy.io
import os

# Base path and file naming structure
base_path = '/media/monica/128 GB/htkCorrectedLab/lab/mat/sylStress/'
file_prefix = 'ISLE_SESS0003_BLOCKD01_'
file_suffix = '_sprt1.mat'

# Prepare to iterate through all file indices
output_list = []

for i in range(1, 82):  # From 1 to 81
    mat_file_name = f"{file_prefix}{i:02d}{file_suffix}"
    wav_file_name = f"{file_prefix}{i:02d}_sprt1.wav"
    file_path = os.path.join(base_path, mat_file_name)
    
    # Load the .mat file
    try:
        mat_contents = scipy.io.loadmat(file_path)
        spurtSyl = mat_contents.get('spurtSyl', [])
        spurtSylTimes = mat_contents.get('spurtSylTimes', [])

        # Prepare syllable data and output in the exact format
        for syllable, times in zip(spurtSyl, spurtSylTimes):
            start_time = float(times[0])
            end_time = float(times[1])
            syllable_text = syllable[0][0]  # Assumed to be the first element of the syllable
            output = f'"{wav_file_name}", [("{syllable_text}", {start_time}, {end_time})]'
            output_list.append(output)

    except FileNotFoundError:
        print(f"File not found: {file_path}")
        continue
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        continue

# Specify the file path where the output should be saved
output_file_path = 'p2tk-code-r18-python-syllabify/SYLLABLEFILE'  # Change this to your desired file path

# Open the output file in write mode and save the results
try:
    with open(output_file_path, 'w') as output_file:
        for line in output_list:
            output_file.write(line + '\n')
    print(f"Output successfully saved to {output_file_path}")
except Exception as e:
    print(f"Error saving output to file: {e}")
# Out:
# Output successfully saved to p2tk-code-r18-python-syllabify/SYLLABLEFILE

# %%
import scipy.io
import os

# Base path and file naming structure
base_path = '/media/monica/128 GB/htkCorrectedLab/lab/mat/sylStress/'
file_prefix = 'ISLE_SESS0003_BLOCKD01_'
file_suffix = '_sprt1.mat'
# Path for phoneme files
phoneme_path = '/media/monica/128 GB/htkCorrectedLab/lab/txt/phn'

# Function to read phoneme data and extract nuclei within a syllable time range
def get_nuclei_from_phn(file_path, syllable_start, syllable_end):
    nuclei = []
    try:
        with open(file_path, 'r') as phn_file:
            for line in phn_file:
                parts = line.strip().split()
                if len(parts) == 3 and parts[2] not in ['SIL']:  # Ignore silence
                    start, end, phoneme = float(parts[0]), float(parts[1]), parts[2]
                    # Check if the phoneme is a vowel and its timing overlaps with the syllable
                    if phoneme in {'A', 'AA', 'AE', 'AH', 'AO', 'AW', 'AY', 'EH', 'ER', 'EY', 'IH', 'IY', 'OW', 'OY', 'UH', 'UW', 'AX', 'AI', 'IX'} and (start >= syllable_start and end <= syllable_end):
                        nuclei.append((phoneme, start, end))
    except FileNotFoundError:
        print(f"Phoneme file not found: {file_path}")
    except Exception as e:
        print(f"Error reading phoneme file {file_path}: {e}")
    return nuclei

# Prepare to iterate through all file indices
output_list = []

for i in range(1, 82):  # From 1 to 81
    mat_file_name = f"{file_prefix}{i:02d}{file_suffix}"
    wav_file_name = f"{file_prefix}{i:02d}_sprt1.wav"
    mat_file_path = os.path.join(base_path, mat_file_name)
    phn_file_path = os.path.join(phoneme_path, f"{file_prefix}{i:02d}{file_suffix.replace('.mat', '.txt')}")
    
    # Load the .mat file
    try:
        mat_contents = scipy.io.loadmat(mat_file_path)
        spurtSyl = mat_contents.get('spurtSyl', [])
        spurtSylTimes = mat_contents.get('spurtSylTimes', [])

        # Prepare syllable data and align with nuclei
        if len(spurtSyl) != len(spurtSylTimes):
            print(f"Warning: Mismatched syllable and time lengths in {mat_file_name}")
        
        for syllable, times in zip(spurtSyl, spurtSylTimes):
            syllable_start = float(times[0])
            syllable_end = float(times[1])
            
            # Extract nuclei (vowel phonemes) within the syllable time range
            nuclei = get_nuclei_from_phn(phn_file_path, syllable_start, syllable_end)
            
            # If no nuclei found, skip this syllable
            if not nuclei:
                continue
            
            # Collect syllable and nucleus data
            syllable_str = " ".join([phoneme[0] for phoneme in syllable])  # Assuming syllable[0] contains phonemes
            for nucleus in nuclei:
                nucleus_phoneme, nucleus_start, nucleus_end = nucleus
                # Format the output for syllable and nucleus
                output = (
                    f'"{wav_file_name}", [("{syllable_str}", {syllable_start:.4f}, {syllable_end:.4f})], '
                    f"[({nucleus_phoneme}, {nucleus_start:.4f}, {nucleus_end:.4f})]"
                )
                output_list.append(output)

    except FileNotFoundError:
        print(f"File not found: {mat_file_path}")
        continue
    except Exception as e:
        print(f"Error processing {mat_file_path}: {e}")
        continue

# Save output to a file
output_file_path = 'p2tk-code-r18-python-syllabify/SYLLABLENUCLUES'  # You can change the file path here

try:
    with open(output_file_path, 'w') as output_file:
        for line in output_list:
            output_file.write(line + '\n')
    print(f"Output successfully saved to {output_file_path}")
except Exception as e:
    print(f"Error saving output to file: {e}")
# Out:
# Output successfully saved to p2tk-code-r18-python-syllabify/SYLLABLENUCLUES

# %%
import scipy.io
import os

# Base path and file naming structure
base_path = '/media/monica/128 GB/htkCorrectedLab/lab/mat/sylStress/'
file_prefix = 'ISLE_SESS0003_BLOCKD01_'
file_suffix = '_sprt1.mat'
# Path for phoneme files
phoneme_path = '/media/monica/128 GB/htkCorrectedLab/lab/txt/phn'

# Function to read phoneme data and extract nuclei within a syllable time range
def get_nuclei_from_phn(file_path, syllable_start, syllable_end):
    nuclei = []
    try:
        with open(file_path, 'r') as phn_file:
            for line in phn_file:
                parts = line.strip().split()
                if len(parts) == 3 and parts[2] not in ['SIL']:  # Ignore silence
                    start, end, phoneme = float(parts[0]), float(parts[1]), parts[2]
                    # Check if the phoneme is a vowel and its timing overlaps with the syllable
                    if phoneme in {'A', 'AA', 'AE', 'AH', 'AO', 'AW', 'AY', 'EH', 'ER', 'EY', 'IH', 'IY', 'OW', 'OY', 'UH', 'UW', 'AX', 'AI'} and (start >= syllable_start and end <= syllable_end):
                        nuclei.append((phoneme, start, end))
    except FileNotFoundError:
        print(f"Phoneme file not found: {file_path}")
    except Exception as e:
        print(f"Error reading phoneme file {file_path}: {e}")
    return nuclei

# Function to get stress values (1 for primary, 0 for unstressed)
def get_stress_value(stress_type):
    if stress_type == 'P':
        return 1
    elif stress_type == 'U':
        return 0
    else:
        return -1  # For handling other stress types (if applicable)

# Prepare to iterate through all file indices
output_list = []

for i in range(1, 82):  # From 1 to 81
    mat_file_name = f"{file_prefix}{i:02d}{file_suffix}"
    wav_file_name = f"{file_prefix}{i:02d}_sprt1.wav"
    mat_file_path = os.path.join(base_path, mat_file_name)
    phn_file_path = os.path.join(phoneme_path, f"{file_prefix}{i:02d}{file_suffix.replace('.mat', '.txt')}")
    
    # Load the .mat file
    try:
        mat_contents = scipy.io.loadmat(mat_file_path)
        spurtSyl = mat_contents.get('spurtSyl', [])
        spurtSylTimes = mat_contents.get('spurtSylTimes', [])
        spurtStress = mat_contents.get('spurtStress', [])

        # Prepare syllable data and align with nuclei
        if len(spurtSyl) != len(spurtSylTimes):
            print(f"Warning: Mismatched syllable and time lengths in {mat_file_name}")
        
        syllables = []
        vowels = []
        stresses = []

        for syllable, times, stress in zip(spurtSyl, spurtSylTimes, spurtStress):
            syllable_start = float(times[0])
            syllable_end = float(times[1])
            
            # Extract nuclei (vowel phonemes) within the syllable time range
            nuclei = get_nuclei_from_phn(phn_file_path, syllable_start, syllable_end)
            
            # If no nuclei found, skip this syllable
            if not nuclei:
                continue
            
            # Collect syllable text
            syllable_str = " ".join([phoneme[0] for phoneme in syllable])  # Assuming syllable[0] contains phonemes
            syllables.append((syllable_str, syllable_start, syllable_end))
            
            # Collect vowel data
            for nucleus in nuclei:
                vowels.append((nucleus[0], nucleus[1], nucleus[2]))
            
            # Collect stress data
            stress_value = get_stress_value(stress[0][0])  # Convert stress to 1 (primary) or 0 (unstressed)
            stresses.append(stress_value)

        # Format the output in the required structure
        syllables_str = str(syllables)
        vowels_str = str(vowels)
        stresses_str = str(stresses)

        output = f'"{wav_file_name}", {syllables_str}, {vowels_str}, {stresses_str}'
        output_list.append(output)

    except FileNotFoundError:
        print(f"File not found: {mat_file_path}")
        continue
    except Exception as e:
        print(f"Error processing {mat_file_path}: {e}")
        continue

# Save output to a file
output_file_path = 'p2tk-code-r18-python-syllabify/SYLLBLESTRESS'  # You can change the file path here

try:
    with open(output_file_path, 'w') as output_file:
        for line in output_list:
            output_file.write(line + '\n')
    print(f"Output successfully saved to {output_file_path}")
except Exception as e:
    print(f"Error saving output to file: {e}")
# Out:
# Output successfully saved to p2tk-code-r18-python-syllabify/SYLLBLESTRESS

# %%
import scipy.io
import os

# Base path and file naming structure
base_path = '/media/monica/128 GB/htkCorrectedLab/lab/mat/sylStress/'
file_prefix = 'ISLE_SESS0006_BLOCKD01_'
file_suffix = '_sprt1.mat'
# Path for phoneme files
phoneme_path = '/media/monica/128 GB/htkCorrectedLab/lab/txt/phn'

# Function to read phoneme data and extract nuclei within a syllable time range
def get_nuclei_from_phn(file_path, syllable_start, syllable_end):
    nuclei = []
    try:
        with open(file_path, 'r') as phn_file:
            for line in phn_file:
                parts = line.strip().split()
                if len(parts) == 3 and parts[2] not in ['SIL']:  # Ignore silence
                    start, end, phoneme = float(parts[0]), float(parts[1]), parts[2]
                    # Check if the phoneme is a vowel and its timing overlaps with the syllable
                    if phoneme in {'A', 'AA', 'AE', 'AH', 'AO', 'AW', 'AY', 'EH', 'ER', 'EY', 'IH', 'IY', 'OW', 'OY', 'UH', 'UW', 'AX', 'AI'} and (start >= syllable_start and end <= syllable_end):
                        nuclei.append((phoneme, start, end))
    except FileNotFoundError:
        print(f"Phoneme file not found: {file_path}")
    except Exception as e:
        print(f"Error reading phoneme file {file_path}: {e}")
    return nuclei

# Function to get stress values (1 for primary, 0 for unstressed)
def get_stress_value(stress_type):
    if stress_type == 'P':
        return 1
    elif stress_type == 'U':
        return 0
    else:
        return -1  # For handling other stress types (if applicable)

# Prepare to iterate through all file indices
output_list = []

for i in range(1, 80):  # From 1 to 80
    mat_file_name = f"{file_prefix}{i:02d}{file_suffix}"
    wav_file_name = f"{file_prefix}{i:02d}_sprt1.wav"
    mat_file_path = os.path.join(base_path, mat_file_name)
    phn_file_path = os.path.join(phoneme_path, f"{file_prefix}{i:02d}{file_suffix.replace('.mat', '.txt')}")
    
    # Load the .mat file
    try:
        mat_contents = scipy.io.loadmat(mat_file_path)
        spurtSyl = mat_contents.get('spurtSyl', [])
        spurtSylTimes = mat_contents.get('spurtSylTimes', [])
        spurtStress = mat_contents.get('spurtStress', [])

        # Prepare syllable data and align with nuclei
        if len(spurtSyl) != len(spurtSylTimes):
            print(f"Warning: Mismatched syllable and time lengths in {mat_file_name}")
        
        syllables = []
        vowels = []
        stresses = []

        for syllable, times, stress in zip(spurtSyl, spurtSylTimes, spurtStress):
            syllable_start = float(times[0])
            syllable_end = float(times[1])
            
            # Extract nuclei (vowel phonemes) within the syllable time range
            nuclei = get_nuclei_from_phn(phn_file_path, syllable_start, syllable_end)
            
            # If no nuclei found, skip this syllable
            if not nuclei:
                continue
            
            # Collect syllable text
            syllable_str = " ".join([phoneme[0] for phoneme in syllable])  # Assuming syllable[0] contains phonemes
            syllables.append((syllable_str, syllable_start, syllable_end))
            
            # Collect vowel data
            for nucleus in nuclei:
                vowels.append((nucleus[0], nucleus[1], nucleus[2]))
            
            # Collect stress data
            stress_value = get_stress_value(stress[0][0])  # Convert stress to 1 (primary) or 0 (unstressed)
            stresses.append(stress_value)

        # Format the output in the required structure
        syllables_str = str(syllables)
        vowels_str = str(vowels)
        stresses_str = str(stresses)

        output = f'"{wav_file_name}", {syllables_str}, {vowels_str}, {stresses_str}'
        output_list.append(output)

    except FileNotFoundError:
        print(f"File not found: {mat_file_path}")
        continue
    except Exception as e:
        print(f"Error processing {mat_file_path}: {e}")
        continue

# Save output to a file
output_file_path = 'p2tk-code-r18-python-syllabify/syllablestress3'  # You can change the file path here

try:
    with open(output_file_path, 'w') as output_file:
        for line in output_list:
            output_file.write(line + '\n')
    print(f"Output successfully saved to {output_file_path}")
except Exception as e:
    print(f"Error saving output to file: {e}")
# Out:
# File not found: /media/monica/128 GB/htkCorrectedLab/lab/mat/sylStress/ISLE_SESS0006_BLOCKD01_28_sprt1.mat
# Output successfully saved to p2tk-code-r18-python-syllabify/syllablestress3
